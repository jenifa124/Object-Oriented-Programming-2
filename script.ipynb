-- %% [markdown]
-- # [HotelDB2]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [HotelDB2]    Script Date: 5/20/2026 9:27:10 PM ******/
CREATE DATABASE [HotelDB2]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'HotelDB2', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL17.SQLEXPRESS\MSSQL\DATA\HotelDB2.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'HotelDB2_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL17.SQLEXPRESS\MSSQL\DATA\HotelDB2_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [HotelDB2] SET COMPATIBILITY_LEVEL = 170
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [HotelDB2].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [HotelDB2] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [HotelDB2] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [HotelDB2] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [HotelDB2] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [HotelDB2] SET ARITHABORT OFF 
GO
ALTER DATABASE [HotelDB2] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [HotelDB2] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [HotelDB2] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [HotelDB2] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [HotelDB2] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [HotelDB2] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [HotelDB2] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [HotelDB2] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [HotelDB2] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [HotelDB2] SET  ENABLE_BROKER 
GO
ALTER DATABASE [HotelDB2] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [HotelDB2] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [HotelDB2] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [HotelDB2] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [HotelDB2] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [HotelDB2] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [HotelDB2] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [HotelDB2] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [HotelDB2] SET  MULTI_USER 
GO
ALTER DATABASE [HotelDB2] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [HotelDB2] SET DB_CHAINING OFF 
GO
ALTER DATABASE [HotelDB2] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [HotelDB2] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [HotelDB2] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [HotelDB2] SET OPTIMIZED_LOCKING = OFF 
GO
ALTER DATABASE [HotelDB2] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [HotelDB2] SET QUERY_STORE = ON
GO
ALTER DATABASE [HotelDB2] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Bookings]

-- %%
USE [HotelDB2]
GO

-- %%
/****** Object:  Table [dbo].[Bookings]    Script Date: 5/20/2026 9:27:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Bookings](
	[bookingId] [int] IDENTITY(1,1) NOT NULL,
	[guestId] [int] NOT NULL,
	[roomId] [int] NOT NULL,
	[checkIn] [date] NOT NULL,
	[checkOut] [date] NOT NULL,
	[status] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[bookingId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FoodOrders]

-- %%
/****** Object:  Table [dbo].[FoodOrders]    Script Date: 5/20/2026 9:27:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FoodOrders](
	[orderId] [int] IDENTITY(1,1) NOT NULL,
	[bookingId] [int] NOT NULL,
	[foodName] [varchar](100) NOT NULL,
	[quantity] [int] NOT NULL,
	[totalPrice] [float] NOT NULL,
	[status] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[orderId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Invoices]

-- %%
/****** Object:  Table [dbo].[Invoices]    Script Date: 5/20/2026 9:27:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Invoices](
	[invoiceId] [int] IDENTITY(1,1) NOT NULL,
	[bookingId] [int] NOT NULL,
	[totalAmount] [float] NOT NULL,
	[paymentDate] [date] NULL,
	[paymentMethod] [varchar](50) NULL,
	[paymentStatus] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[invoiceId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Login]

-- %%
/****** Object:  Table [dbo].[Login]    Script Date: 5/20/2026 9:27:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Login](
	[loginId] [int] IDENTITY(1,1) NOT NULL,
	[userId] [int] NOT NULL,
	[password] [varchar](100) NOT NULL,
	[role] [varchar](50) NOT NULL,
	[status] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[loginId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Rooms]

-- %%
/****** Object:  Table [dbo].[Rooms]    Script Date: 5/20/2026 9:27:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Rooms](
	[roomId] [int] IDENTITY(1,1) NOT NULL,
	[roomType] [varchar](50) NOT NULL,
	[pricePerNight] [float] NOT NULL,
	[status] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[roomId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Services]

-- %%
/****** Object:  Table [dbo].[Services]    Script Date: 5/20/2026 9:27:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Services](
	[serviceId] [int] IDENTITY(1,1) NOT NULL,
	[serviceName] [varchar](100) NOT NULL,
	[cost] [float] NOT NULL,
	[bookingId] [int] NOT NULL,
	[status] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[serviceId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 5/20/2026 9:27:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[userId] [int] IDENTITY(1,1) NOT NULL,
	[userName] [varchar](100) NOT NULL,
	[email] [varchar](100) NOT NULL,
	[phoneNumber] [varchar](20) NULL,
	[role] [varchar](50) NOT NULL,
	[status] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[userId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Bookings__status__5535A963]

-- %%
ALTER TABLE [dbo].[Bookings] ADD  DEFAULT ('Pending') FOR [status]
GO

-- %% [markdown]
-- # [DF__FoodOrder__statu__619B8048]

-- %%
ALTER TABLE [dbo].[FoodOrders] ADD  DEFAULT ('Pending') FOR [status]
GO

-- %% [markdown]
-- # [DF__Invoices__paymen__5DCAEF64]

-- %%
ALTER TABLE [dbo].[Invoices] ADD  DEFAULT ('Unpaid') FOR [paymentStatus]
GO

-- %% [markdown]
-- # [DF__Login__status__4E88ABD4]

-- %%
ALTER TABLE [dbo].[Login] ADD  DEFAULT ((1)) FOR [status]
GO

-- %% [markdown]
-- # [DF__Rooms__status__52593CB8]

-- %%
ALTER TABLE [dbo].[Rooms] ADD  DEFAULT ('Available') FOR [status]
GO

-- %% [markdown]
-- # [DF__Services__status__59FA5E80]

-- %%
ALTER TABLE [dbo].[Services] ADD  DEFAULT ('Active') FOR [status]
GO

-- %% [markdown]
-- # [DF__Users__status__4BAC3F29]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT ('Active') FOR [status]
GO

-- %% [markdown]
-- # [FK__Bookings__guestI__5629CD9C]

-- %%
ALTER TABLE [dbo].[Bookings]  WITH CHECK ADD FOREIGN KEY([guestId])
REFERENCES [dbo].[Users] ([userId])
GO

-- %% [markdown]
-- # [FK__Bookings__roomId__571DF1D5]

-- %%
ALTER TABLE [dbo].[Bookings]  WITH CHECK ADD FOREIGN KEY([roomId])
REFERENCES [dbo].[Rooms] ([roomId])
GO

-- %% [markdown]
-- # [FK__FoodOrder__booki__628FA481]

-- %%
ALTER TABLE [dbo].[FoodOrders]  WITH CHECK ADD FOREIGN KEY([bookingId])
REFERENCES [dbo].[Bookings] ([bookingId])
GO

-- %% [markdown]
-- # [FK__Invoices__bookin__5EBF139D]

-- %%
ALTER TABLE [dbo].[Invoices]  WITH CHECK ADD FOREIGN KEY([bookingId])
REFERENCES [dbo].[Bookings] ([bookingId])
GO

-- %% [markdown]
-- # [FK__Login__userId__4F7CD00D]

-- %%
ALTER TABLE [dbo].[Login]  WITH CHECK ADD FOREIGN KEY([userId])
REFERENCES [dbo].[Users] ([userId])
GO

-- %% [markdown]
-- # [FK__Services__bookin__5AEE82B9]

-- %%
ALTER TABLE [dbo].[Services]  WITH CHECK ADD FOREIGN KEY([bookingId])
REFERENCES [dbo].[Bookings] ([bookingId])
GO

-- %% [markdown]
-- # [HotelDB2]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [HotelDB2] SET  READ_WRITE 
GO
